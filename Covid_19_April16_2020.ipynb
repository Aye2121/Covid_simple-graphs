# %%
from datapackage import Package
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
cases = pd.read_csv(r"C:\Aye backup\Python\Udemy\zero-to-mastery-ml-master\COVID_19\worldwide-aggregated_csv_Apr16.csv")

# %%
cases.head()
# Out:
#          Date  Confirmed  Recovered  Deaths  Increase rate
# 0  2020-01-22        555         28      17            NaN
# 1  2020-01-23        654         30      18      17.837838
# 2  2020-01-24        941         36      26      43.883792
# 3  2020-01-25       1434         39      42      52.391073
# 4  2020-01-26       2118         52      56      47.698745

# %%
cases["Date"] = pd.to_datetime(cases["Date"])

# %%
cases.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 85 entries, 0 to 84
# Data columns (total 5 columns):
# Date             85 non-null datetime64[ns]
# Confirmed        85 non-null int64
# Recovered        85 non-null int64
# Deaths           85 non-null int64
# Increase rate    84 non-null float64
# dtypes: datetime64[ns](1), float64(1), int64(3)
# memory usage: 3.4 KB

# %%
cases.head()
# Out:
#         Date  Confirmed  Recovered  Deaths  Increase rate
# 0 2020-01-22        555         28      17            NaN
# 1 2020-01-23        654         30      18      17.837838
# 2 2020-01-24        941         36      26      43.883792
# 3 2020-01-25       1434         39      42      52.391073
# 4 2020-01-26       2118         52      56      47.698745

# %%
# adding new rate of change columns
cases["Deaths_change"] = cases["Deaths"].pct_change()*100
cases["Recovered_change"] = cases["Recovered"].pct_change()*100

# %%
cases.rename(columns={"Deaths_change": "Increase Rate (Deaths)", 
                      "Recovered_change": "Increase rate (Recovered)",
                     "Increase rate": "Increase rate(Confirmed)"}, inplace= True)

# %%
cases.tail()
# Out:
#          Date  Confirmed  Recovered  Deaths  Increase rate(Confirmed)  \
# 80 2020-04-11    1771514     402110  108503                  4.716800
# 81 2020-04-12    1846679     421722  114091                  4.242981
# 82 2020-04-13    1917319     448655  119482                  3.825245
# 83 2020-04-14    1976191     474261  125984                  3.070538
# 84 2020-04-15    2056054     511019  134177                  4.041259
#
#     Increase Rate (Deaths)  Increase rate (Recovered)
# 80                5.830773                   6.916851
# 81                5.150088                   4.877272
# 82                4.725176                   6.386435
# 83                5.441824                   5.707281
# 84                6.503207                   7.750585

# %%
fig, axs = plt.subplots(figsize=(15,5))

plt.plot("Date", "Deaths", data = cases, color='red', marker='o', linestyle='dashed', linewidth=2)
plt.plot("Date", "Recovered", data = cases, color='green', marker='o', linestyle='dashed', linewidth=2)
plt.plot("Date", "Confirmed", data = cases, color='yellow', marker='o', linestyle='dashed', linewidth=2)

plt.legend()

# %%
# rate of Increase in death, recovered and confirmed  cases compared to the precious day

fig, axs = plt.subplots(figsize=(15,5))

plt.plot("Date", "Increase Rate (Deaths)", data = cases, color='red', marker='o', linestyle='dashed', linewidth=2)
plt.plot("Date", "Increase rate (Recovered)", data = cases, color='green', marker='o', linestyle='dashed', linewidth=2)
plt.plot("Date", "Increase rate(Confirmed)", data = cases, color='yellow', marker='o', linestyle='dashed', linewidth=2)

plt.legend()
